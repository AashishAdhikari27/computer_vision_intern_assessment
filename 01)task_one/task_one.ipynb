# %% [markdown]
# # Task 1: Basic Image Manipulation
#
# **Objective:** Test your OpenCV basics.
#
# **Task:**
# Load any image of your choice.
#
# Apply the following operations and save the outputs:
#
# - Convert to grayscale.
# - Apply Gaussian Blur.
# - Detect edges using Canny Edge Detector.
#
# **Deliverables:**
# 3 processed images + source code.

# %%
# importing libraries 

import pandas as pd
import numpy as np

import cv2 ##  importing opencv lirary 
# we can just import it as "import cv2 as cv " only too 

import matplotlib.pyplot as plt

# %%
image_path = '01)task_one/bear.jpg'

# loading image using opencv
image = cv2.imread(image_path)

# %%
print(image)          # prints the raw pixel values (as a NumPy array)

print(type(image))    # confirms the data type
# Out:
# [[[153 181 128]
#   [150 180 127]
#   [148 179 124]
#   ...
#   [124 175 147]
#   [132 177 151]
#   [136 178 153]]
#
#  [[145 175 122]
#   [143 175 120]
#   [140 175 119]
#   ...
#   [122 173 145]
#   [126 173 147]
#   [129 174 148]]
#
#  [[136 173 117]
#   [136 173 117]
#   [133 172 116]
#   ...
#   [121 173 143]
#   [123 172 144]
#   [125 173 145]]
#
#  ...
#
#  [[194 238 199]
#   [158 212 169]
#   [109 181 134]
#   ...
#   [ 86 172 110]
#   [129 200 144]
#   [165 229 177]]
#
#  [[104 149 110]
#   [  5  59  16]
#   [ 63 135  89]
#   ...
#   [118 197 130]
#   [131 201 140]
#   [128 194 135]]
#
#  [[111 164 121]
#   [ 82 143  99]
#   [118 193 149]
#   ...
#   [118 198 121]
#   [ 89 182 107]
#   [ 68 167  93]]]
# <class 'numpy.ndarray'>

# %%
# to visualize the image in a separate popup window, which is preferred for .py files 
cv2.imshow('Bear Image', image)
cv2.waitKey(0)      # Waits for any key press
cv2.destroyAllWindows()  # Closes all windows

# %%
#for the jupyter notebook (i.e for .ipynb files) we can view the image in the notebook using matplotlib 

#As imread() method loads the image in the BGR 8-bit format which is default.So, converting BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.title('Bear Image')
plt.axis('off')
plt.show()

# %% [markdown]
# # Converting image in grayscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # convers the bgr image to gray image using .cvtColor() function 
# for documentation : https://docs.opencv.org/4.11.0/d8/d01/group__imgproc__color__conversions.html#gga4e0972be5de079fed4e3a10e24ef5ef0a353a4b8db9040165db4dacb5bcefb6ea

cv2.imwrite('01)task_one/output_images/bear_gray.jpg', gray_image)  # this saves the converted gray image to desired file location with desired name
# Out:
# True

# %%
# Display the grayscale image using matplotlib
plt.imshow(gray_image, cmap='gray')  # 'cmap=gray' is important for grayscale images
plt.title('Grayscale Image')         # Optional title
plt.axis('off')                      # Hides the axes for better visual
plt.show()

# %% [markdown]
# # Applying gaussian blur
# Gaussian Blur is a commonly used image processing technique to reduce image noise and detail. It's especially useful as a preprocessing step in tasks like edge detection (e.g., Canny), object detection, or image smoothing.
#
# ### for more detailed information visit this documentation : https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html

# %%
# Applied Gaussian Blur to the grayscale image
blurred_gray_image = cv2.GaussianBlur(gray_image, (5, 5), 0)  # kernel size = (5,5), sigmaX = 0

# Save the blurred image
cv2.imwrite('01)task_one/output_images/bear_grey_blur.jpg', blurred_image)


# Applied Gaussian Blur to the original image
blurred_image = cv2.GaussianBlur(image, (5, 5), 0)  # kernel size = (5,5), sigmaX = 0

# Save the blurred image
cv2.imwrite('01)task_one/output_images/bear_blur.jpg', blurred_image)
# Out:
# True

# %%
# Display the blurred gray image using matplotlib
plt.imshow(blurred_image, cmap='gray')  # 'cmap=gray' ensures correct display for grayscale images
plt.title('Gaussian Blurred Image')
plt.axis('off')  # Hides the axis for a cleaner look
plt.show()

# %% [markdown]
# # Canny Edge Detection :-
# Canny Edge Detection is a multi-step algorithm used to detect a wide range of edges in images. It's one of the most popular and effective edge detection techniques available in OpenCV.
#
# ### For more details visit this documentation : https://docs.opencv.org/4.x/da/d22/tutorial_py_canny.html

# %%
edges = cv2.Canny(blurred_image,100,200)   # applying canny edge detection to the blurred original image as blurrd one is more smooth

# Saving the edge detection image
cv2.imwrite('01)task_one/output_images/bear_canny_edge_detection.jpg', edges)
# Out:
# True

# %%
plt.subplot(121),plt.imshow(blurred_image,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
 
plt.show()
